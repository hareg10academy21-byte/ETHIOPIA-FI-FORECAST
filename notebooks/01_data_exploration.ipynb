# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.0

# %%
import os

print(os.path.exists("data/raw/ethiopia_fi_unified_data.csv"))
# Out:
# False

# %%
import pandas as pd

df = pd.read_csv(
    "../data/raw/ethiopia_fi_unified_data.csv"
)

print(df.head())
# Out:
#   record_id  record_type category  pillar               indicator  \
# 0  REC_0001  observation      NaN  ACCESS  Account Ownership Rate
# 1  REC_0002  observation      NaN  ACCESS  Account Ownership Rate
# 2  REC_0003  observation      NaN  ACCESS  Account Ownership Rate
# 3  REC_0004  observation      NaN  ACCESS  Account Ownership Rate
# 4  REC_0005  observation      NaN  ACCESS  Account Ownership Rate
#
#   indicator_code indicator_direction  value_numeric value_text  value_type  \
# 0  ACC_OWNERSHIP       higher_better           22.0        NaN  percentage
# 1  ACC_OWNERSHIP       higher_better           35.0        NaN  percentage
# 2  ACC_OWNERSHIP       higher_better           46.0        NaN  percentage
# 3  ACC_OWNERSHIP       higher_better           56.0        NaN  percentage
# 4  ACC_OWNERSHIP       higher_better           36.0        NaN  percentage
#
#    ... impact_direction impact_magnitude impact_estimate lag_months  \
# ...

# %%
df.shape
# Out:
# (43, 34)

# %%
df.columns
# Out:
# Index(['record_id', 'record_type', 'category', 'pillar', 'indicator',
#        'indicator_code', 'indicator_direction', 'value_numeric', 'value_text',
#        'value_type', 'unit', 'observation_date', 'period_start', 'period_end',
#        'fiscal_year', 'gender', 'location', 'region', 'source_name',
#        'source_type', 'source_url', 'confidence', 'related_indicator',
#        'relationship_type', 'impact_direction', 'impact_magnitude',
#        'impact_estimate', 'lag_months', 'evidence_basis', 'comparable_country',
#        'collected_by', 'collection_date', 'original_text', 'notes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   record_id            43 non-null     object
#  1   record_type          43 non-null     object
#  2   category             10 non-null     object
#  3   pillar               33 non-null     object
#  4   indicator            43 non-null     object
#  5   indicator_code       43 non-null     object
#  6   indicator_direction  33 non-null     object
#  7   value_numeric        33 non-null     float64
#  8   value_text           10 non-null     object
#  9   value_type           43 non-null     object
#  10  unit                 33 non-null     object
#  11  observation_date     43 non-null     object
#  12  period_start         10 non-null     object
#  13  period_end           10 non-null     object
#  14  fiscal_year          43 non-null     object
# ...

# %%
df.describe(include="all")
# Out:
#        record_id  record_type        category  pillar               indicator  \
# count         43           43              10      33                      43
# unique        43            3               7       4                      29
# top     REC_0001  observation  product_launch  ACCESS  Account Ownership Rate
# freq           1           30               2      16                       7
# mean         NaN          NaN             NaN     NaN                     NaN
# std          NaN          NaN             NaN     NaN                     NaN
# min          NaN          NaN             NaN     NaN                     NaN
# 25%          NaN          NaN             NaN     NaN                     NaN
# 50%          NaN          NaN             NaN     NaN                     NaN
# 75%          NaN          NaN             NaN     NaN                     NaN
# max          NaN          NaN             NaN     NaN                     NaN
#
# ...

# %%
df["record_type"].value_counts()
# Out:
# record_type
# observation    30
# event          10
# target          3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

df["record_type"].value_counts().plot(
    kind="bar"
)

plt.title("Distribution of Record Types")
plt.xlabel("Record Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# The dataset contains observations, events, impact links, and targets which collectively describe Ethiopia's financial inclusion ecosystem.

# %%
df["pillar"].value_counts()
# Out:
# pillar
# ACCESS           16
# USAGE            11
# GENDER            5
# AFFORDABILITY     1
# Name: count, dtype: int64

# %%
df["pillar"].unique()
# Out:
# array(['ACCESS', 'USAGE', 'AFFORDABILITY', 'GENDER', nan], dtype=object)

# %%
df["pillar"].value_counts().plot(
    kind="bar"
)

plt.title("Distribution of Financial Inclusion Pillars")
plt.show()

# %%
df["source_type"].value_counts()
# Out:
# source_type
# operator      15
# survey        10
# regulator      7
# research       4
# policy         3
# calculated     2
# news           2
# Name: count, dtype: int64

# %%
df["source_type"].value_counts().plot(
    kind="bar"
)

plt.title("Distribution of Source Types")
plt.show()

# %%
df["confidence"].value_counts()
# Out:
# confidence
# high      40
# medium     3
# Name: count, dtype: int64

# %%
df["confidence"].value_counts().plot(
    kind="bar"
)

plt.title("Confidence Levels")
plt.show()

# %%
observations = df[
    df["record_type"]=="observation"
]

# %%
observations["observation_date"]
# Out:
# 0     2014-12-31
# 1     2017-12-31
# 2     2021-12-31
# 3     2021-12-31
# 4     2021-12-31
# 5     2024-11-29
# 6     2021-12-31
# 7     2024-11-29
# 8     2023-06-30
# 9     2025-06-30
# 10    2025-12-31
# 11    2024-08-15
# 12    2025-02-28
# 13    2025-05-15
# 14    2024-07-07
# 15    2025-07-07
# 16    2025-07-07
# 17    2025-07-07
# 18    2025-07-07
# 19    2025-07-07
# 20    2025-06-30
# 21    2025-06-30
# 22    2024-12-31
# 23    2024-12-31
# 24    2024-12-31
# 25    2024-12-31
# 26    2021-12-31
# 27    2024-11-29
# 28    2024-12-31
# 29    2024-12-31
# Name: observation_date, dtype: object

# %%
observations["observation_date"]=pd.to_datetime(

    observations["observation_date"]

)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_20616\2911189933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   observations["observation_date"]=pd.to_datetime(

# %%
observations["observation_date"].min()
# Out:
# Timestamp('2014-12-31 00:00:00')

# %%
observations["observation_date"].max()
# Out:
# Timestamp('2025-12-31 00:00:00')

# %%
df["indicator"].unique()
# Out:
# array(['Account Ownership Rate', 'Mobile Money Account Rate',
#        '4G Population Coverage', 'Mobile Subscription Penetration',
#        'Fayda Digital ID Enrollment', 'P2P Transaction Count',
#        'P2P Transaction Value', 'ATM Transaction Count',
#        'ATM Transaction Value', 'P2P/ATM Crossover Ratio',
#        'Telebirr Registered Users', 'Telebirr Transaction Value',
#        'M-Pesa Registered Users', 'M-Pesa 90-Day Active Users',
#        'Mobile Money Activity Rate', 'Data Affordability Index',
#        'Account Ownership Gender Gap',
#        'Female Mobile Money Account Share', 'Mobile Phone Gender Gap',
#        'Telebirr Launch', 'Safaricom Ethiopia Commercial Launch',
#        'M-Pesa Ethiopia Launch', 'Fayda Digital ID Program Rollout',
#        'Foreign Exchange Liberalization',
#        'P2P Transaction Count Surpasses ATM',
#        'M-Pesa EthSwitch Integration',
#        'EthioPay Instant Payment System Launch',
# ...

# %%
df["indicator_code"].unique()
# Out:
# array(['ACC_OWNERSHIP', 'ACC_MM_ACCOUNT', 'ACC_4G_COV', 'ACC_MOBILE_PEN',
#        'ACC_FAYDA', 'USG_P2P_COUNT', 'USG_P2P_VALUE', 'USG_ATM_COUNT',
#        'USG_ATM_VALUE', 'USG_CROSSOVER', 'USG_TELEBIRR_USERS',
#        'USG_TELEBIRR_VALUE', 'USG_MPESA_USERS', 'USG_MPESA_ACTIVE',
#        'USG_ACTIVE_RATE', 'AFF_DATA_INCOME', 'GEN_GAP_ACC',
#        'GEN_MM_SHARE', 'GEN_GAP_MOBILE', 'EVT_TELEBIRR', 'EVT_SAFARICOM',
#        'EVT_MPESA', 'EVT_FAYDA', 'EVT_FX_REFORM', 'EVT_CROSSOVER',
#        'EVT_MPESA_INTEROP', 'EVT_ETHIOPAY', 'EVT_NFIS2',
#        'EVT_SAFCOM_PRICE'], dtype=object)

# %%
df.groupby(

    "indicator"

)["record_id"].count()
# Out:
# indicator
# 4G Population Coverage                    2
# ATM Transaction Count                     1
# ATM Transaction Value                     1
# Account Ownership Gender Gap              2
# Account Ownership Rate                    7
# Data Affordability Index                  1
# EthioPay Instant Payment System Launch    1
# Fayda Digital ID Enrollment               4
# Fayda Digital ID Program Rollout          1
# Female Mobile Money Account Share         2
# Foreign Exchange Liberalization           1
# M-Pesa 90-Day Active Users                1
# M-Pesa EthSwitch Integration              1
# M-Pesa Ethiopia Launch                    1
# M-Pesa Registered Users                   1
# Mobile Money Account Rate                 2
# Mobile Money Activity Rate                1
# Mobile Phone Gender Gap                   1
# Mobile Subscription Penetration           1
# NFIS-II Strategy Launch                   1
# P2P Transaction Count                     2
# ...

# %%
df.groupby(

    "indicator"

)["record_id"].count().plot(

    kind="bar"

)

plt.show()

# %%
events=df[

    df["record_type"]=="event"

]

# %%
events.head()
# Out:
#    record_id record_type        category pillar  \
# 33  EVT_0001       event  product_launch    NaN
# 34  EVT_0002       event    market_entry    NaN
# 35  EVT_0003       event  product_launch    NaN
# 36  EVT_0004       event  infrastructure    NaN
# 37  EVT_0005       event          policy    NaN
#
#                                indicator indicator_code indicator_direction  \
# 33                       Telebirr Launch   EVT_TELEBIRR                 NaN
# 34  Safaricom Ethiopia Commercial Launch  EVT_SAFARICOM                 NaN
# 35                M-Pesa Ethiopia Launch      EVT_MPESA                 NaN
# 36      Fayda Digital ID Program Rollout      EVT_FAYDA                 NaN
# 37       Foreign Exchange Liberalization  EVT_FX_REFORM                 NaN
#
#     value_numeric   value_text   value_type  ... impact_direction  \
# 33            NaN     Launched  categorical  ...              NaN
# 34            NaN     Launched  categorical  ...              NaN
# ...

# %%
events = df[df["record_type"]=="event"]

# %%
events.head()
# Out:
#    record_id record_type        category pillar  \
# 33  EVT_0001       event  product_launch    NaN
# 34  EVT_0002       event    market_entry    NaN
# 35  EVT_0003       event  product_launch    NaN
# 36  EVT_0004       event  infrastructure    NaN
# 37  EVT_0005       event          policy    NaN
#
#                                indicator indicator_code indicator_direction  \
# 33                       Telebirr Launch   EVT_TELEBIRR                 NaN
# 34  Safaricom Ethiopia Commercial Launch  EVT_SAFARICOM                 NaN
# 35                M-Pesa Ethiopia Launch      EVT_MPESA                 NaN
# 36      Fayda Digital ID Program Rollout      EVT_FAYDA                 NaN
# 37       Foreign Exchange Liberalization  EVT_FX_REFORM                 NaN
#
#     value_numeric   value_text   value_type  ... impact_direction  \
# 33            NaN     Launched  categorical  ...              NaN
# 34            NaN     Launched  categorical  ...              NaN
# ...

# %%
events.columns
# Out:
# Index(['record_id', 'record_type', 'category', 'pillar', 'indicator',
#        'indicator_code', 'indicator_direction', 'value_numeric', 'value_text',
#        'value_type', 'unit', 'observation_date', 'period_start', 'period_end',
#        'fiscal_year', 'gender', 'location', 'region', 'source_name',
#        'source_type', 'source_url', 'confidence', 'related_indicator',
#        'relationship_type', 'impact_direction', 'impact_magnitude',
#        'impact_estimate', 'lag_months', 'evidence_basis', 'comparable_country',
#        'collected_by', 'collection_date', 'original_text', 'notes'],
#       dtype='object')

# %%
for column in events.columns:
    print(column)
# Out:
# record_id
# record_type
# category
# pillar
# indicator
# indicator_code
# indicator_direction
# value_numeric
# value_text
# value_type
# unit
# observation_date
# period_start
# period_end
# fiscal_year
# gender
# location
# region
# source_name
# source_type
# source_url
# confidence
# related_indicator
# relationship_type
# impact_direction
# impact_magnitude
# impact_estimate
# lag_months
# evidence_basis
# comparable_country
# collected_by
# collection_date
# original_text
# notes

# %%
events.T
# Out:
#                                                                33  \
# record_id                                                EVT_0001
# record_type                                                 event
# category                                           product_launch
# pillar                                                        NaN
# indicator                                         Telebirr Launch
# indicator_code                                       EVT_TELEBIRR
# indicator_direction                                           NaN
# value_numeric                                                 NaN
# value_text                                               Launched
# value_type                                            categorical
# unit                                                          NaN
# observation_date                                       2021-05-17
# period_start                                                  NaN
# ...

# %%
events[
[
"record_id",
"category",
"value_text",
"observation_date"
]
]
# Out:
#    record_id        category   value_text observation_date
# 33  EVT_0001  product_launch     Launched       2021-05-17
# 34  EVT_0002    market_entry     Launched       2022-08-01
# 35  EVT_0003  product_launch     Launched       2023-08-01
# 36  EVT_0004  infrastructure     Launched       2024-01-01
# 37  EVT_0005          policy  Implemented       2024-07-29
# 38  EVT_0006       milestone     Achieved       2024-10-01
# 39  EVT_0007     partnership     Launched       2025-10-27
# 40  EVT_0008  infrastructure     Launched       2025-12-18
# 41  EVT_0009          policy     Launched       2021-09-01
# 42  EVT_0010         pricing  Implemented       2025-12-15

# %%
events = df[df["record_type"] == "event"]

events.shape
# Out:
# (10, 34)

# %%
events[
[
"record_id",
"category",
"value_text",
"observation_date",
"source_name",
"confidence"
]
]
# Out:
#    record_id        category   value_text observation_date    source_name  \
# 33  EVT_0001  product_launch     Launched       2021-05-17  Ethio Telecom
# 34  EVT_0002    market_entry     Launched       2022-08-01           News
# 35  EVT_0003  product_launch     Launched       2023-08-01      Safaricom
# 36  EVT_0004  infrastructure     Launched       2024-01-01           NIDP
# 37  EVT_0005          policy  Implemented       2024-07-29            NBE
# 38  EVT_0006       milestone     Achieved       2024-10-01      EthSwitch
# 39  EVT_0007     partnership     Launched       2025-10-27      EthSwitch
# 40  EVT_0008  infrastructure     Launched       2025-12-18  NBE/EthSwitch
# 41  EVT_0009          policy     Launched       2021-09-01            NBE
# 42  EVT_0010         pricing  Implemented       2025-12-15           News
#
#    confidence
# 33       high
# 34       high
# 35       high
# 36       high
# 37       high
# 38       high
# 39       high
# 40       high
# ...

# %%
events["category"].value_counts()
# Out:
# category
# product_launch    2
# infrastructure    2
# policy            2
# market_entry      1
# milestone         1
# partnership       1
# pricing           1
# Name: count, dtype: int64

# %%
impact_links = df[df["record_type"]=="impact_link"]

impact_links.shape
# Out:
# (0, 34)

# %%
impact_links.head()
# Out:
# Empty DataFrame
# Columns: [record_id, record_type, category, pillar, indicator, indicator_code, indicator_direction, value_numeric, value_text, value_type, unit, observation_date, period_start, period_end, fiscal_year, gender, location, region, source_name, source_type, source_url, confidence, related_indicator, relationship_type, impact_direction, impact_magnitude, impact_estimate, lag_months, evidence_basis, comparable_country, collected_by, collection_date, original_text, notes]
# Index: []
#
# [0 rows x 34 columns]

# %%
impact_links[
[
"record_id",
"pillar",
"related_indicator",
"impact_direction",
"impact_magnitude",
"lag_months",
"evidence_basis"
]
]
# Out:
# Empty DataFrame
# Columns: [record_id, pillar, related_indicator, impact_direction, impact_magnitude, lag_months, evidence_basis]
# Index: []

# %%
impact_links.columns
# Out:
# Index(['record_id', 'record_type', 'category', 'pillar', 'indicator',
#        'indicator_code', 'indicator_direction', 'value_numeric', 'value_text',
#        'value_type', 'unit', 'observation_date', 'period_start', 'period_end',
#        'fiscal_year', 'gender', 'location', 'region', 'source_name',
#        'source_type', 'source_url', 'confidence', 'related_indicator',
#        'relationship_type', 'impact_direction', 'impact_magnitude',
#        'impact_estimate', 'lag_months', 'evidence_basis', 'comparable_country',
#        'collected_by', 'collection_date', 'original_text', 'notes'],
#       dtype='object')

# %%
impact_links["impact_direction"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
impact_links["relationship_type"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
impact_links[
[
"record_id",
"pillar",
"related_indicator",
"impact_direction",
"impact_magnitude",
"lag_months",
"evidence_basis"
]
].head(20)
# Out:
# Empty DataFrame
# Columns: [record_id, pillar, related_indicator, impact_direction, impact_magnitude, lag_months, evidence_basis]
# Index: []

# %%
import pandas as pd

new_events = pd.DataFrame({

"record_id":[
"EV_NEW_001",
"EV_NEW_002",
"EV_NEW_003",
"EV_NEW_004",
"EV_NEW_005"
],

"record_type":[
"event",
"event",
"event",
"event",
"event"
],

"category":[
"product_launch",
"product_launch",
"policy",
"infrastructure",
"infrastructure"
],

"pillar":[
"",
"",
"",
"",
""
],

"value_text":[
"Telebirr Mobile Money Launch",
"M-Pesa Ethiopia Launch",
"National Financial Inclusion Strategy II",
"Fayda Digital ID Expansion",
"EthSwitch Payment Infrastructure Expansion"
],

"observation_date":[
"2021-05-11",
"2023-05-08",
"2021-01-01",
"2023-01-01",
"2020-01-01"
],

"source_name":[
"Ethio Telecom",
"Safaricom Ethiopia",
"National Bank of Ethiopia",
"National ID Program Ethiopia",
"EthSwitch"
],

"confidence":[
"high",
"high",
"high",
"medium",
"medium"
],

"collected_by":[
"Haregeweyn",
"Haregeweyn",
"Haregeweyn",
"Haregeweyn",
"Haregeweyn"
],

"collection_date":[
"2026-07-19",
"2026-07-19",
"2026-07-19",
"2026-07-19",
"2026-07-19"
]

})


new_events
# Out:
#     record_id record_type        category pillar  \
# 0  EV_NEW_001       event  product_launch
# 1  EV_NEW_002       event  product_launch
# 2  EV_NEW_003       event          policy
# 3  EV_NEW_004       event  infrastructure
# 4  EV_NEW_005       event  infrastructure
#
#                                    value_text observation_date  \
# 0                Telebirr Mobile Money Launch       2021-05-11
# 1                      M-Pesa Ethiopia Launch       2023-05-08
# 2    National Financial Inclusion Strategy II       2021-01-01
# 3                  Fayda Digital ID Expansion       2023-01-01
# 4  EthSwitch Payment Infrastructure Expansion       2020-01-01
#
#                     source_name confidence collected_by collection_date
# 0                 Ethio Telecom       high   Haregeweyn      2026-07-19
# 1            Safaricom Ethiopia       high   Haregeweyn      2026-07-19
# 2     National Bank of Ethiopia       high   Haregeweyn      2026-07-19
# ...

# %%
new_events.to_csv(
"../data/processed/enriched_events.csv",
index=False
)

# %%
new_links = pd.DataFrame({

"parent_id":[
"EV_NEW_001",
"EV_NEW_002",
"EV_NEW_003",
"EV_NEW_004",
"EV_NEW_005"
],

"pillar":[
"USAGE",
"USAGE",
"ACCESS",
"ACCESS",
"USAGE"
],

"related_indicator":[
"DIGITAL_PAYMENT_USAGE",
"MOBILE_MONEY_ACCOUNT",
"ACCOUNT_OWNERSHIP",
"ACCOUNT_OWNERSHIP",
"DIGITAL_PAYMENT_USAGE"
],

"impact_direction":[
"positive",
"positive",
"positive",
"positive",
"positive"
],

"impact_magnitude":[
"high",
"medium",
"medium",
"medium",
"medium"
],

"lag_months":[
6,
6,
12,
12,
6
],

"evidence_basis":[
"Mobile money expansion increases digital transactions",
"Mobile money competition increases account access",
"Digital identity improves access to formal financial services",
"Digital ID reduces onboarding barriers",
"Payment infrastructure improves electronic transactions"

]

})


new_links
# Out:
#     parent_id  pillar      related_indicator impact_direction  \
# 0  EV_NEW_001   USAGE  DIGITAL_PAYMENT_USAGE         positive
# 1  EV_NEW_002   USAGE   MOBILE_MONEY_ACCOUNT         positive
# 2  EV_NEW_003  ACCESS      ACCOUNT_OWNERSHIP         positive
# 3  EV_NEW_004  ACCESS      ACCOUNT_OWNERSHIP         positive
# 4  EV_NEW_005   USAGE  DIGITAL_PAYMENT_USAGE         positive
#
#   impact_magnitude  lag_months  \
# 0             high           6
# 1           medium           6
# 2           medium          12
# 3           medium          12
# 4           medium           6
#
#                                       evidence_basis
# 0  Mobile money expansion increases digital trans...
# 1  Mobile money competition increases account access
# 2  Digital identity improves access to formal fin...
# 3             Digital ID reduces onboarding barriers
# 4  Payment infrastructure improves electronic tra...

# %%
new_links.to_csv(
"../data/processed/enriched_impact_links.csv",
index=False
)

# %%
combined = pd.concat(
[
df,
new_events
],
ignore_index=True
)


combined.shape
# Out:
# (48, 34)

# %%
combined.to_csv(
"../data/processed/ethiopia_fi_enriched_dataset.csv",
index=False
)
